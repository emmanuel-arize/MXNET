# %% [markdown]
# # Linear Regression
# linear regression is one of the most widely used regression models.This asserts that the is a linear function betweent the target variable (response) and the inputs variables (features) and it is a useful tool for predicting a quantitative response.
#
#
# # Linear Model
#
#  Suppose as a data scientist in your company, you are tasked to predict the price of houses based on the age and area of a housing data presented to you because your comapny wants to purchase a company house next year. In machine learning, our goal is generalized well so to have a good predictions on newly unseen data so we mostly divided the dataset into training data or training set (mostly 70-80% of the dataset) which will be used in training our model and the rest as test set on which we will test our model to sea good the model is when predicting newly unseen data becuase after training our model what we will be predictions are going to be similar (new) but unseen inputs. The rows of the dataset are called instances (observations or examples) and what we want to predict is called a target or label or dependent variable or response. The variables upon which the predictions are based are called features or covariates or independent variables (any column value in the input dataset).
#
#
# # As a data scientist you first task is to ask
#
#  $\bullet$ Is there a relationship between age and price of a house or area and price of a house.Are these relations negative (negative in the sense that when one increase the other decrease and vise versa) or positive (when one increases the other increases).
#
#  Does new or old houses have high or low prices and vice versa
#
#  $\bullet$ How strong is the relationship between these features and the price of a house. Which feature contribute most to the price of a house
#
#  $\bullet$ Is the relationship linear?
#
# Using linear regression assumes that there is approximately a linear relationship between features and the target variables and this linearity assumption says that the target (price) can be expressed as a weighted sum of the features
#
#
#
# using age and area of a house as features in predictint the price of a house the linearity assumption  says that the target (price) can be expressed as a weighted sum of the features (area and age) given by:
#
# $$ price = w_{1} *area + w_{2} * age + b$$
#
# let assume we have 3 rows then
#
# $$
# \begin{array}{ccc}
# price_{1} = w_{0} + w_{1} *area_{1,1} + w_{2} * age_{1,2} \\
# price_{2} = w_{0} + w_{1} *area_{2,1} + w_{2} * age_{2,2} \\
# price_{3} = w_{0} + w_{1} *area_{3,1} + w_{2} * age_{3,2}
# \end{array}$$
#
# $$price = \left|\begin{array}{ccc}
# 1&area_{1,1} &  age_{1,2} \\
# 1&area_{2,1} &  age_{2,2}\\
# 1&area_{3,1} & age_{3,2}
# \end{array}\right| \left|\begin{array}{ccc}
# w_{0} \\
# w_{1}\\
# w_{2}
# \end{array}\right|=X*w
# $$
#
# where $w_{1}$ and $w_{2}$ are weights(parameters) associted with area and age respectively and determine the influence of each feature on our prediction, and $b (w_{0}$ is called a bias(parameter) (also called an offset or intercept) which accounts for factors that are not accounted for by the input variables
#
# When our inputs consist of
# d features, we express our prediction $\hat y$ as
# $\hat y = w_{1}·x_{1} +... + w_{d} · x_{d} + b$
# Collecting all features into a vector $x$ and all weights into a vector w, we can express our model
# compactly using a dot product:
# $$\hat y = w^{T} X + b=Xw + b$$ or $$\hat y = w^{T} X$$ here the $$w_{o}= bias$$
#
# here $X$ is the data points and $w$ is the weight vector
#
#
# Even if the best model for predicting y given x is linear, we would not expect to find real-world data where $y_{i}$ exactly equals $w^{⊤}x + b$ for all points $(x, y)$. For example, whatever instruments we use to observe the features X and labels y might suffer small amount of measurement error. Thus, even when we are confident that the underlying relationship is linear, we will incorporate a noise term to account for such errors.
#
#
# $\textbf{Before} $ we can go about searching for the best parameters w and b which will generalized well, we will need two more things:
# (i) a quality measure for some given model; and (ii) a procedure for updating the model parameters to improve its quality predictions

# %% [markdown]
# # Loss Function
# Our next step is to select a performance measure that will determine how good our model fit the data by measuring the closeness of our predictions to their real values. The loss function quantifies the distance between the actual or real and predicted value with a goal to minimize the prediction error for data points not used during training. The loss will usually be a non-negative number where smaller values are better and perfect predictions incur a loss of 0
#
#
#
# # sum of squared errors
#
# the sum of squared errors is the most popular loss function in regression problems and is given by
#
# $$\ell_{i}(w,b)=\frac{1}{2}(y_{i}-\hat y_{i})^{2}$$
#
#  The fraction 1⁄2 is arbitrary, and is used for mathematical convenience
#
# in general to measure the quality of our model on the entire dataset, we simply average the losses on the training set
# $$\ell(w,b)=\frac{1}{2n} \sum_{1}^{n}(w^{T} X_{i}+b -y_{i})^{2}$$
#
# during training we want to find the best parameters $(w∗,b∗)$ that minimize the total loss across all training samples:
# $$w∗, b∗ = argmin_{w,b}L(w, b)$$
#
#
#
#
# # Analytic Solution
# Linear regression happens to be a simple optimization problem
#
# $$\ell(w)=(w^{T} X -y_{i})^{2}$$
# $$\ell(w)=(w X -y)^{T}(w^{T} X -y)$$
#
# $$\ell=ww^{T}x_{T}x-2w^{T}xy+yy^{T} $$
#
# $$ \frac{\partial \ell}{\partial  w} =2wx^{T}x-2xy=0$$
# $$w=(x^{T}x)^{-1}xy$$

# %% [markdown]
# # UPDATING PARAMETERS
# during trainiing we want to automatically update the parameters in order the find the best parameters that minimize the error. We use Gradient descent in updating the parameters
#
# # Learning with the Delta Rule
# Now suppose we have $$\hat y=u=w_{1}x$$
#
# then the error is given as
# $$ E=y- \hat y$$
#
# and the square error $\epsilon$ for an input is given as
# $$ \epsilon =\frac{1}{2}E^{2}=\frac{1}{2}(y- \hat y)^{2} $$
#
#
# To find the gradient at a particular weight we differentiate the square error function with respect to that particular weight  (here we are have w1), yielding
# $$\frac{d \epsilon}{dw_{1}} =\frac{2}{2}(y- w_{1}x)(-x)=-Ex $$
#
#
# Using the delta rule, a change in weight is proportional to the negative of the error gradient because it is necessary to go down the error curve in order to minimize the error; therefore, the weight change is given by:
#
# $$ \Delta w_{1}\propto -Ex$$
#
# where $\propto$ denotes proportionality, which can be replaced with learning rate $\beta$.
#
# The learning rate is tuning parameter which determines
#
# how big a step is taking along the gradient in order to find a better weight. A too high value for $\beta$ will make the learning jump over  the minima but smaller values slow it down and will take too long to converge.Using
# $\beta$ the eqution becomes
# $$ \Delta w_{1}=-\beta Ex$$
#
#  The new weight after the ith iteration canbe expressed as
#
# $$ W_{1}^{i+1}=W_{1}^{i}- \Delta w_{1}=W_{1}^{i}-\beta Ex $$
#
#
# using the same idea we can extend to
# $$ W_{j}^{i+1}=W_{j}^{i}-\Delta w_{j}^{i}=W_{j}^{i}-\beta Ex_{j}$$
# $$ W_{0}^{i+1}=W_{0}^{i}-\beta E$$
# where $W_{0}$ is the bias

# %% [markdown]
# # Gradient Descent
#
# Gradient Descent is generic optimization algorithm capable of finding optimal solutions to a wide range of problems with th goal
# of iteratively reducing the error by tweaking (updating) the parameters in the direction that incrementally lowers the loss function.
#
# # stochastic gradient descent
# When training the model, it is preferable to wait use the whole training set to compute the gradients at every step and this is known as $\textbf{Batch Gradient Descent}$ but this can slow the training of our model when the training set is large so instead we mostly used a random sample of the training set in updating the parameters and is  called $\textbf{stochastic gradient descent}$.
#
#
# $\textbf{stochastic gradient descent}$ is a stochastic approximation proximation of the gradient descent with the fact that the gradient is precisely not know, but instead so we make a rough approximation to the gradient in order to minimize an objective function which is written as a sum of differentiable functions
#
#
#
#
# $$ \Delta w_{1}=\beta (\frac{1}{n} \sum^{n}Ex_{i})  $$
# where n is the batch size
#
# # hyper-parameters
#
# the batch size and learning rate are manually pre-specified and not typically learned through model training. These parameters
# that are tunable but not updated in the training loop are called hyper-parameters.
#
# Hyperparameter tuning is the process by which pre-specified parameter are chosen, and typically requires that we adjust the hyperparameters based on the results of the inner (training) loop as assessed on a separate validation
# split of the data.

# %% [markdown]
# # BACKPROPAGATION

# %%
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline
# Out:
# C:\Anaconda3\lib\site-packages\numpy\_distributor_init.py:32: UserWarning: loaded more than 1 DLL from .libs:
# C:\Anaconda3\lib\site-packages\numpy\.libs\libopenblas.PYQHXLVVQ7VESDPUVUADXEVJOBGHJPAY.gfortran-win_amd64.dll
# C:\Anaconda3\lib\site-packages\numpy\.libs\libopenblas.TXA6YQSD3GCQQC22GEQ54J2UDCXDXHWN.gfortran-win_amd64.dll
#   stacklevel=1)

# %%
back=plt.imread('back.png')
plt.imshow(back)
plt.show()

# %% [markdown]
# suppose we have a model of the form
# $$f(w1,w2,w3)=(w1+w2)w3$$ and $$q=w1+w2$$ with initial values
# w1=-1,w2=2 and w3=-2
#
# using these initial values for the first iteration
# $$q=-1+2=1$$
# and $$f=q*w3=1*-2=-2$$
#
# in order to update the weights we will differentiate f with respect to the variables
#
# $ \frac{\partial q}{\partial w1}=1 $, $  \frac{\partial q}{\partial w2}=1 $, $  \frac{\partial f}{\partial q}=w3=-2 $,
# $  \frac{\partial f}{\partial w3}=q=1 $,
# $ \frac{\partial f }{\partial w1}=\frac{\partial f }{\partial q}\frac{\partial q}{\partial w1}=-2*1=-2$,
# $ \frac{\partial f }{\partial w2}=\frac{\partial f }{\partial q}\frac{\partial q}{\partial w2}=-2*1=-2$
#
# After updating the weights, the new weights becomes
# $$w1=\frac{\partial f }{\partial w1}=\frac{\partial f }{\partial q}\frac{\partial q}{\partial w1}=-2*1=-2$$
# $$w2= \frac{\partial f }{\partial w2}=\frac{\partial f }{\partial q}\frac{\partial q}{\partial w2}=-2*1=-2$$
#
# $$q= \frac{\partial f}{\partial q}=w3=-2 $$
# $  w3=\frac{\partial f}{\partial w3}=q=1 $

# %% [markdown]
# # Normal Distribution
# ---
#
#
# $$  p(y)=\frac{1}{ \sqrt[]{2 \pi \sigma^2}} \exp(-\frac{1}{2 \sigma^2}(y-\mu )^{2} )$$
#
#
#
# One way to motivate linear regression with the mean squared error loss function is to formally
# assume that observations arise from noisy observations, where the noise is normally distributed
# as follows
# $$ y = w^{T} X + b + \varepsilon= Xw + b$$ where $\varepsilon \backsim N(\mu(x), \sigma^{2}) $
#
# We often assume $E(\varepsilon)=\mu(x) = 0$ and $var(\varepsilon) = \sigma ^{2}$. It is the random error  reflecting the difference between the observed and fitted linear relationship.
#
#
#
# Thus, we can now write out the likelihood of seeing a particular y for a given x via
#
# $$p(y|x)=\frac{1}{\sqrt{2 \pi \sigma^{2}}} \exp( \frac{-1}{ 2  \sigma^{2}}(y-w^{T}x-b)^{2})$$
#
# connecting linear regression and Gaussians, we can rewrite
# the model in the following form:
# $$ p(y|x,\theta)=N(y | \mu(x), \sigma^{2}(x))  $$
#
# where y is a noisy function values (targets) and x is the inputs
#
# This shows that the model is a conditional probability density. If we assume $\mu$ is a linear function of x, then $\mu = w^{T} x$,  the noise is fixed, $\sigma^{2}(x) =\sigma^{2}$ and $\theta = (w, \sigma^{2})$ are the parameters of the model.
#
#
# the  relationship between x and y is given as
#
# $$ y =\mu(x) + \varepsilon= Xw + b +\varepsilon $$ where $\varepsilon \backsim N(\mu(x), \sigma^{2})$
#
# Our objective now is to find a function that is close or similar to the unknown function $\mu$ that generated the dataset and that generalizes well
#
#
# Now, according to the maximum likelihood principle, the best values of b and w are those that maximize the likelihood of the entire dataset:
#
#
# $$P(Y|X)=\prod_{i}^{n}p(y^{i}|x^{i} ) $$
#
#  While, maximizing the product of many exponential functions, might look difficult, we can simplify things significantly, without changing the objective, by maximizing the log of the likelihood instead.  optimizations are more often expressed as minimization rather than maximization. So, without changing anything we can minimize the Negative Log-Likelihood (NLL) $-logp(y|x)$
#
#
# $$-logp(y|x)=\sum_{i}^{n} \frac{1}{2}log(2 \pi \sigma^{2}  + \frac{1}{2\sigma^{2}}(y^{i}-w^{T}x^{i}-b)^{2}$$
#
#
#  $\sigma$ is some fixed constant and we can ignore the first term since it does not depend on w or b. Now the second term is identical to the squared error objective introduced earlier, but for the multiplicative constant $\frac{1}{2 \sigma^{2}}$ the solution does not depend on it so this follows that minimizing squared error is equivalent to maximum likelihood estimation of a linear model under the assumption of additive Gaussian noise

# %%
import math
import numpy as np
import d2l
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
def normal(z,mu,sigma):
    p=1/math.sqrt(2*math.pi * sigma**2)
    q=-0.5/ sigma**2
    return p*np.exp( q*(z-mu)**2)

# %%
x = np.arange(-7,7, 0.01)
b=normal(x,mu=0,sigma=1)
x
# Out:
# array([-7.  , -6.99, -6.98, ...,  6.97,  6.98,  6.99])

# %%
parameters = [(0, 1), (0, 2), (3, 1)]
for mu, sigma in parameters:
    plt.plot(x,normal(x,mu,sigma),label=['mean',mu,'var',sigma])
    plt.legend()

# %%
parameters = [(0, 1), (0, 2), (3, 1),(2,4),(0,5)]
d2l.plot(x, [normal(x, mu, sigma) for mu, sigma in parameters], xlabel='z',ylabel='p(z)', 
         figsize=(4.5, 2.5),legend=['mean %d, var %d' % (mu, sigma) for mu, sigma in parameters])

# %% [markdown]
# from the diagram above one can see that changing the mean corresponds to a shift along the x axis, and increasing the
# variance spreads the distribution out, lowering its peak.

# %% [markdown]
# # Linear Regression Implementation from Scratch

# %%
import d2l
from mxnet import np,npx,autograd,nd
import random
import mxnet
# %matplotlib inline
mxnet.random.seed(10)
# Out:
# C:\Anaconda3\lib\site-packages\numpy\_distributor_init.py:32: UserWarning: loaded more than 1 DLL from .libs:
# C:\Anaconda3\lib\site-packages\numpy\.libs\libopenblas.PYQHXLVVQ7VESDPUVUADXEVJOBGHJPAY.gfortran-win_amd64.dll
# C:\Anaconda3\lib\site-packages\numpy\.libs\libopenblas.TXA6YQSD3GCQQC22GEQ54J2UDCXDXHWN.gfortran-win_amd64.dll
#   stacklevel=1)

# %% [markdown]
# # Generating the Dataset
#
# the synthetic dataset generated will be an object $ X\in R^{1000×2}.$
# where 1000 is the number of examples (observations) and 2 is the number of features

# %%
# Saved in the d2l package for later use
def synthetic_data(w, b, num_examples):
    """Generate y = X w + b + noise."""
    # np.random.normal(mean,std,size=(rows,columns))
    X = np.random.normal(0, 1, (num_examples, len(w)))
    y = np.dot(X, w) + b
    # y=y+np.random.normal(0, 0.01, y.shape)
    y += np.random.normal(0, 0.01, y.shape)
    return X, y
true_w = np.array([2, -3.4])
true_b = 4.2
features, labels = synthetic_data(true_w, true_b, 1000)

# %%
print('the data contain '+ str(features.shape[0])+' observations with ' + 
      str(features.shape[1]) +' features(dimension) \n hence a '+ str(features.shape[0]) 
      +" by " + str(features.shape[1])+' matrix' )
# Out:
# the data contain 1000 observations with 2 features(dimension)
#  hence a 1000 by 2 matrix

# %%
labels.shape
# Out:
# (1000,)

# %%
#first 3 observations
features[:3]
# Out:
# array([[ 0.8076988 ,  0.8197375 ],
#        [ 0.00439439, -0.5273536 ],
#        [ 1.4724891 ,  0.15160327]])

# %%
# first 2 observations within the target variable
labels[:2]
# Out:
# array([3.0313442, 6.001063 ])

# %% [markdown]
#  correlation between the first feature and the target variable(labels) which shows a positive correlation
# To plot with matplotlib we'll need to convert X and y into NumPy arrays by using the .asnumpy() function.

# %%
d2l.set_figsize((3.5, 2.5))
d2l.plt.scatter(features[:, 0].asnumpy(), labels.asnumpy(), 1);

# %% [markdown]
# correlation between the second feature and the target variable(labels) which shows a negative correlation. To plot with matplotlib we'll need to convert X and y into NumPy arrays by using the .asnumpy() function.

# %%
d2l.set_figsize((3.5, 3.5))
d2l.plt.scatter(features[:, 1].asnumpy(), labels.asnumpy(), 1);

# %%
def data_iter(batch_size, features, labels):
    num_examples=len(features)# features.shape[0]
    indices=list(range(num_examples))
    # The examples are read at random, in no particular order
    random.shuffle(indices)
    for i in range(0,num_examples,batch_size):
        batch_indices=np.array(indices[i:min(i+batch_size,num_examples)])
        yield features[batch_indices],labels[batch_indices]

# %%
# letʼs read and print the first small batch of data examples
batch_size = 10
for X, y in data_iter(batch_size, features, labels):
    print(X, '\n \n', y)
    break
# Out:
# [[-0.9797156  -0.50803334]
#  [ 1.0582831  -0.2877359 ]
#  [ 0.63893634 -1.1765771 ]
#  [-1.2125769  -1.5594131 ]
#  [ 0.4635112  -0.53213656]
#  [-0.7698851   1.5024068 ]
#  [-0.3774059  -0.7017118 ]
#  [ 0.6719617  -1.4907118 ]
#  [-0.18844941  0.0089968 ]
#  [-1.5343051   0.9981327 ]]
#
#  [ 3.9729424  7.3150735  9.491026   7.0629163  6.9386597 -2.444314
#   5.817819  10.615432   3.7886887 -2.2657776]

# %%
batch_size = 10
for i, (X, y) in enumerate( data_iter(batch_size, features, labels)):
    print(X, '\n \n', y)
    break
# Out:
# [[ 0.7892089   0.9498683 ]
#  [ 0.49458274  0.14497128]
#  [ 1.1196667  -0.07574534]
#  [ 0.5160403  -1.2453216 ]
#  [ 1.018746    0.703299  ]
#  [-0.8586056  -0.55400455]
#  [-0.19197625 -1.2826823 ]
#  [ 0.25983986  0.47058275]
#  [-0.50961405  0.34717026]
#  [-1.1610966   1.1776149 ]]
#
#  [ 2.5372157  4.6770515  6.7067847  9.456646   3.8474534  4.36491
#   8.18136    3.1239824  1.996705  -2.1291192]

# %% [markdown]
# # Initializing Model Parameters

# %% [markdown]
#  initializing the weights by sampling random numbers from a normal distribution with mean 0 and a standard deviation of 0:01,
# setting the bias b to 0.

# %%
w = np.random.normal(0, 0.01, (2, 1))
b = np.zeros(1)

# %% [markdown]
# Now that we have initialized our parameters, our next task is to update the various weight and biases until they fit our data
# sufficiently well so as to minimize the error.
#
# updating parameters requires taking the gradient (a multi-dimensional derivative) of our loss function with respect to the parameters. Given this gradient, we can update each parameter in the direction that reduces the loss.

# %%
# We allocate memory for an ndarrayʼs gradient by invoking its attach_grad method.
w.attach_grad()
b.attach_grad()

# %% [markdown]
# the calculated gradient taken with respect to x, can be access via the grad attribute with default initialized as an array containing all zeros.

# %%
w.grad,b.grad
# Out:
# (array([[0.],
#         [0.]]), array([0.]))

# %% [markdown]
# # Defining the Model

# %%
def linreg(X):
    return np.dot(X, w) + b

# %% [markdown]
# # Defining the Loss Function
# updating our model requires taking the gradient of our loss function, so we need to define
#  squared loss function as loss our function for our model. we need to transform the true value y into the predicted valueʼs
# shape y_hat

# %%
def square_loss(y_hat, y):
    return 0.5*(y_hat - y.reshape(y_hat.shape)) ** 2

# %% [markdown]
# # Defining the Optimization Algorithm
# ---

# %% [markdown]
#  # stochastic gradient descent
#  stochastic gradient descent is used as our optimization algorithm

# %%
#  stochastic gradient descent (SGD)
def sgd(params, lr, batch_size):
    for para in params:
        para[:]=para-lr*para.grad/batch_size

# %%
lr = 0.01 # Learning rate
num_epochs = 10 # Number of iterations

for epoch in range(num_epochs):
    for X,y in data_iter(batch_size,features,labels):
        with autograd.record():
            y_hat=linreg(X)
            loss=square_loss(y_hat,y)# Minibatch loss in X and y
        loss.backward() # Compute gradient on l with respect to [w, b]
        sgd([w, b], lr, batch_size) # Update parameters using their gradient
    train_l = square_loss(linreg(features), labels)
    print('epoch %d, loss %f' % (epoch + 1, train_l.mean().asnumpy()))
# Out:
# epoch 1, loss 0.266627
# epoch 2, loss 0.033285
# epoch 3, loss 0.004210
# epoch 4, loss 0.000571
# epoch 5, loss 0.000115
# epoch 6, loss 0.000058
# epoch 7, loss 0.000051
# epoch 8, loss 0.000050
# epoch 9, loss 0.000050
# epoch 10, loss 0.000050

# %% [markdown]
#  because we synthesized the data ourselves, we know precisely what the true parameters are. Thus, we can evaluate our success in training by comparing the true parameters with those that we learned through our training loop.

# %%
print('Error in estimating w', true_w - w.reshape(true_w.shape))
print('Error in estimating b', true_b - b)
# Out:
# Error in estimating w [-9.9897385e-05 -9.2983246e-06]
# Error in estimating b [0.00024509]

# %% [markdown]
# # Concise Implementation of Linear Regression
# ----

# %%
import d2l
from mxnet import autograd, gluon, np, npx
npx.set_np()
true_w = np.array([2, -3.4])
true_b = 4.2
features, labels = d2l.synthetic_data(true_w, true_b, 1000)

# %%
#??gluon.data.ArrayDataset

# %%
#??gluon.data.DataLoader

# %% [markdown]
# Rather than rolling our own iterator, we can call upon Gluonʼs data module to read data

# %%
# Saved in the d2l package for later use
def load_array(data_arrays, batch_size):
    dataset=gluon.data.ArrayDataset(*data_arrays)
    return gluon.data.DataLoader(dataset,batch_size,shuffle=True)

# %%
batch_size = 10
data_iter = load_array((features, labels), batch_size)

# %%
# printing the first batch
for X,y in data_iter:
    print(X,y)
    break
# Out:
# [[ 1.5058986  -1.7817048 ]
#  [-0.14232115  1.1515478 ]
#  [ 0.05352175  0.4427563 ]
#  [ 0.5524764   0.08506036]
#  [ 1.3073908   0.57250184]
#  [-0.28162912 -1.0621238 ]
#  [ 0.6886306   0.49508455]
#  [ 0.70873517 -1.5176686 ]
#  [ 0.05511785  0.24637266]
#  [-0.53291225  1.5433066 ]] [ 1.3282875e+01 -3.5701187e-03  2.8028500e+00  5.0107126e+00
#   4.8573332e+00  7.2434053e+00  3.9014981e+00  1.0767855e+01
#   3.4633832e+00 -2.1217840e+00]

# %% [markdown]
# # Defining the Model

# %%
from mxnet.gluon import nn
net=nn.Sequential()

# %%
net.add(nn.Dense(1))

# %% [markdown]
# # Initializing Model Parameters
#
# initializing the parameter (weights and bias) randomly from a normal distribution with mean 0 and standard deviation 0:01.
# Both the weight vector and bias will have attached gradients

# %%
#??init.Uniform

# %%
from mxnet import init
net.initialize(init.Normal(sigma=0.01))

# %% [markdown]
# #  Defining the Loss Function

# %%
from mxnet.gluon import loss

# %%
#help(loss.L2Loss)

# %%
# # The squared loss is also known as the L2 norm loss
l2_loss=loss.L2Loss()

# %% [markdown]
# # Defining the Optimization Algorithm

# %%
#  parameters to optimize is from net via net.collect_params())
# optimizer=sgd
trainer = gluon.Trainer(net.collect_params(),'sgd',{'learning_rate': 0.01})

# %% [markdown]
# # Training

# %%
num_epochs=10
for epoch in range(num_epochs+1):
    for X,y in data_iter:
        with autograd.record():
            l2=l2_loss(net(X),y)# Minibatch loss in X and y
        l2.backward()
        trainer.step(batch_size)
    l2=l2_loss(net(features),labels)
    print('epoch %d, loss: %f' % (epoch, l2.mean().asnumpy()))
# Out:
# epoch 0, loss: 2.415206
# epoch 1, loss: 0.387550
# epoch 2, loss: 0.062314
# epoch 3, loss: 0.010076
# epoch 4, loss: 0.001667
# epoch 5, loss: 0.000311
# epoch 6, loss: 0.000093
# epoch 7, loss: 0.000058
# epoch 8, loss: 0.000053
# epoch 9, loss: 0.000052
# epoch 10, loss: 0.000051

# %%
w = net[0].weight.data()
print('Error in estimating w', true_w.reshape(w.shape) - w)
b = net[0].bias.data()
print('Error in estimating b', true_b - b)
# Out:
# Error in estimating w [[7.7962875e-05 1.8143654e-04]]
# Error in estimating b [0.00080156]

# %%
from mxnet.gluon import nn,loss
from mxnet import init
import d2l
from mxnet import autograd, gluon, np, npx
import random
import matplotlib.pyplot as plt
import pandas as pd
import os
# %matplotlib inline
npx.set_np()

# %% [markdown]
# below is a function to load the needed dataset

# %%
def load_data(path='./data'):
    data=os.path.join(path,'Lemonade.csv')
    return pd.read_csv(data)

data=load_data()

# %% [markdown]
# Showing the first 7 examples of the dataset (both the features and target variable)

# %%
data.head(7)
# Out:
#          Date        Day  Temperature  Rainfall  Flyers  Price  Sales
# 0  01/01/2017     Sunday         27.0      2.00      15    0.3     10
# 1  02/01/2017     Monday         28.9      1.33      15    0.3     13
# 2  03/01/2017    Tuesday         34.5      1.33      27    0.3     15
# 3  04/01/2017  Wednesday         44.1      1.05      28    0.3     17
# 4  05/01/2017   Thursday         42.4      1.00      33    0.3     18
# 5  06/01/2017     Friday         25.3      1.54      23    0.3     11
# 6  07/01/2017   Saturday         32.9      1.54      19    0.3     13

# %% [markdown]
# showing first few examples of the features

# %% [markdown]
# showing first few examples of the features

# %%
data.iloc[:,:-1].head()
# Out:
#          Date        Day  Temperature  Rainfall  Flyers  Price
# 0  01/01/2017     Sunday         27.0      2.00      15    0.3
# 1  02/01/2017     Monday         28.9      1.33      15    0.3
# 2  03/01/2017    Tuesday         34.5      1.33      27    0.3
# 3  04/01/2017  Wednesday         44.1      1.05      28    0.3
# 4  05/01/2017   Thursday         42.4      1.00      33    0.3

# %% [markdown]
# showing first few examples of the target variable sales

# %%
data.iloc[:,[-1]].head()
# Out:
#    Sales
# 0     10
# 1     13
# 2     15
# 3     17
# 4     18

# %%
print( 'the dataset has '+str(data.iloc[:,:-1].shape[0])+" examples with " +str(data.iloc[:,:-1].shape[1])+ " features")
# Out:
# the dataset has 365 examples with 6 features

# %% [markdown]
# $\textbf{we are interested in determining whether sales increases with rainy or high temperature }$ days so we are dropping the date and day feature because our focus is not to determine which day increase sales but to know when sales increase base on sunny on rainy day

# %%
data.drop(['Date','Day'],axis=1,inplace=True)

# %%
data.head(3)
# Out:
#    Temperature  Rainfall  Flyers  Price  Sales
# 0         27.0      2.00      15    0.3     10
# 1         28.9      1.33      15    0.3     13
# 2         34.5      1.33      27    0.3     15

# %%
print( 'After dropping the date and day features the dataset now has '+str(data.iloc[:,:-1].shape[1])+
      ' features with '+str(data.iloc[:,:-1].shape[0])+" examples")
# Out:
# After dropping the date and day features the dataset now has 4 features with 365 examples

# %% [markdown]
# checking for correlation between the inputs and the target variable

# %%
from pandas.plotting import scatter_matrix

# %%
scatter_matrix(data,alpha=0.36,figsize=(10,10))
plt.show()

# %% [markdown]
# from the above diagram we see that
#
# $\bullet$ there is $\textbf{positive correlation between sales and temperature}$  that is sales increase with high temperature and vice versa so for the company to increase it sales it has to make sure it's able to sell a lot of flyers on sunny day becuase sales decreases during rainny days
#
# $\bullet$ there is a $\textbf{negative correlation between sales and rainfall} $ that is sales decreases with high rainfall and vice versa
#
# $\bullet$ there is a $\textbf{negative correlation between Temperature and rainfall} $ that is Temperature decreases with high rainfall and vice versa
#
#
# $\bullet$ there is $\textbf{positive correlation between sales and Flyers}$  that is sales increase when a lot of flyers are sold and vice versa which means sales increases when a lot of flyers are sold

# %% [markdown]
# Computing pairwise correlation of between columns

# %%
data.corr()
# Out:
#              Temperature  Rainfall    Flyers     Price     Sales
# Temperature     1.000000 -0.902859  0.797719  0.504709  0.989832
# Rainfall       -0.902859  1.000000 -0.747389 -0.383775 -0.909214
# Flyers          0.797719 -0.747389  1.000000  0.405437  0.805183
# Price           0.504709 -0.383775  0.405437  1.000000  0.512908
# Sales           0.989832 -0.909214  0.805183  0.512908  1.000000

# %%
from sklearn.preprocessing import StandardScaler
imputs=data.iloc[:,:-1]
imputs.head()
# Out:
#    Temperature  Rainfall  Flyers  Price
# 0         27.0      2.00      15    0.3
# 1         28.9      1.33      15    0.3
# 2         34.5      1.33      27    0.3
# 3         44.1      1.05      28    0.3
# 4         42.4      1.00      33    0.3

# %% [markdown]
# Scaling the features so that all values are within the same range

# %%
# creating a scaling object
scaler=StandardScaler()
imputs=scaler.fit_transform(imputs)

# %%
def load_array(features,labels, batch_size):
    dataset=gluon.data.ArrayDataset(*(features,labels))
    dataloader=gluon.data.DataLoader(dataset=dataset,batch_size=batch_size,shuffle=True)
    return dataloader

# %%
target=np.array(data.iloc[:,[-1]])
inputs=np.array(imputs)

# %%
train_loader=load_array(features=inputs,labels=target,batch_size=100)

# %%
for x,y in train_loader:
    print(x.dtype)
    break
# Out:
# <class 'numpy.float32'>

# %% [markdown]
# Defining the Model

# %%
net=nn.Sequential()

# %% [markdown]
# In Gluon, the fully-connected layer is defined in the Dense class. Since we
# only want to generate a single scalar output, we set that number to 1

# %%
net.add(nn.Dense(1))

# %%
net.collect_params()
# Out:
# sequential1_ (
#   Parameter dense1_weight (shape=(1, -1), dtype=float32)
#   Parameter dense1_bias (shape=(1,), dtype=float32)
# )

# %% [markdown]
# # Initializing Model Parameters¶
# initializing the parameter (weights and bias) randomly from a normal distribution with mean 0 and standard deviation 0:01. Both the weight vector and bias will have attached gradients

# %%
net.initialize(init.Normal(sigma=0.01))

# %%
loss=loss.L2Loss()

# %%
trainer=gluon.Trainer(net.collect_params(),'sgd',{'learning_rate':0.02})

# %%
batch_size=100
num_epochs=500
for epoch in range(num_epochs+1):
    for X,y in train_loader:
        with autograd.record():
            y_pred=net(X)
            l2=loss(y_pred,y)
        l2.backward()
        trainer.step(batch_size)
    loss_f=loss(net(inputs),target)
    print('epoch %d, loss: %f' % (epoch, loss_f.mean().asnumpy()))
# Out:
# epoch 0, loss: 292.390442
# epoch 1, loss: 249.495529
# epoch 2, loss: 213.475555
# epoch 3, loss: 183.129257
# epoch 4, loss: 157.371399
# epoch 5, loss: 135.458145
# epoch 6, loss: 116.741623
# epoch 7, loss: 100.697487
# epoch 8, loss: 86.920502
# epoch 9, loss: 75.088280
# epoch 10, loss: 64.905792
# epoch 11, loss: 56.142368
# epoch 12, loss: 48.585873
# epoch 13, loss: 42.072258
# epoch 14, loss: 36.453190
# epoch 15, loss: 31.608047
# epoch 16, loss: 27.424200
# epoch 17, loss: 23.816393
# epoch 18, loss: 20.700842
# epoch 19, loss: 18.010136
# epoch 20, loss: 15.687855
# epoch 21, loss: 13.682823
# epoch 22, loss: 11.951774
# epoch 23, loss: 10.456140
# epoch 24, loss: 9.163535
# epoch 25, loss: 8.047648
# epoch 26, loss: 7.083223
# epoch 27, loss: 6.249563
# epoch 28, loss: 5.528396
# epoch 29, loss: 4.904943
# epoch 30, loss: 4.365199
# epoch 31, loss: 3.898604
# epoch 32, loss: 3.495110
# epoch 33, loss: 3.145340
# epoch 34, loss: 2.842048
# epoch 35, loss: 2.579536
# epoch 36, loss: 2.351648
# epoch 37, loss: 2.154196
# epoch 38, loss: 1.982778
# epoch 39, loss: 1.833621
# epoch 40, loss: 1.703850
# epoch 41, loss: 1.591017
# epoch 42, loss: 1.492725
# epoch 43, loss: 1.407010
# epoch 44, loss: 1.332067
# epoch 45, loss: 1.266402
# epoch 46, loss: 1.208791
# epoch 47, loss: 1.158361
# epoch 48, loss: 1.113998
# epoch 49, loss: 1.074822
# epoch 50, loss: 1.040180
# epoch 51, loss: 1.009438
# epoch 52, loss: 0.982182
# epoch 53, loss: 0.957950
# epoch 54, loss: 0.936173
# epoch 55, loss: 0.916642
# epoch 56, loss: 0.899049
# epoch 57, loss: 0.883158
# epoch 58, loss: 0.868802
# epoch 59, loss: 0.855683
# epoch 60, loss: 0.843716
# epoch 61, loss: 0.832649
# epoch 62, loss: 0.822508
# epoch 63, loss: 0.813080
# epoch 64, loss: 0.804318
# epoch 65, loss: 0.796187
# epoch 66, loss: 0.788538
# epoch 67, loss: 0.781357
# epoch 68, loss: 0.774558
# epoch 69, loss: 0.768117
# epoch 70, loss: 0.761971
# epoch 71, loss: 0.756105
# epoch 72, loss: 0.750495
# epoch 73, loss: 0.745120
# epoch 74, loss: 0.739961
# epoch 75, loss: 0.734984
# epoch 76, loss: 0.730187
# epoch 77, loss: 0.725543
# epoch 78, loss: 0.721034
# epoch 79, loss: 0.716646
# epoch 80, loss: 0.712381
# epoch 81, loss: 0.708229
# epoch 82, loss: 0.704180
# epoch 83, loss: 0.700225
# epoch 84, loss: 0.696358
# epoch 85, loss: 0.692586
# epoch 86, loss: 0.688874
# epoch 87, loss: 0.685259
# epoch 88, loss: 0.681704
# epoch 89, loss: 0.678225
# epoch 90, loss: 0.674809
# epoch 91, loss: 0.671448
# epoch 92, loss: 0.668150
# epoch 93, loss: 0.664907
# epoch 94, loss: 0.661727
# epoch 95, loss: 0.658598
# epoch 96, loss: 0.655517
# epoch 97, loss: 0.652490
# epoch 98, loss: 0.649508
# epoch 99, loss: 0.646576
# epoch 100, loss: 0.643692
# epoch 101, loss: 0.640855
# epoch 102, loss: 0.638061
# epoch 103, loss: 0.635311
# epoch 104, loss: 0.632602
# epoch 105, loss: 0.629931
# epoch 106, loss: 0.627302
# epoch 107, loss: 0.624712
# epoch 108, loss: 0.622161
# epoch 109, loss: 0.619644
# epoch 110, loss: 0.617168
# epoch 111, loss: 0.614721
# epoch 112, loss: 0.612314
# epoch 113, loss: 0.609942
# epoch 114, loss: 0.607599
# epoch 115, loss: 0.605284
# epoch 116, loss: 0.603009
# epoch 117, loss: 0.600764
# epoch 118, loss: 0.598552
# epoch 119, loss: 0.596369
# epoch 120, loss: 0.594214
# epoch 121, loss: 0.592092
# epoch 122, loss: 0.590001
# epoch 123, loss: 0.587931
# epoch 124, loss: 0.585895
# epoch 125, loss: 0.583887
# epoch 126, loss: 0.581906
# epoch 127, loss: 0.579951
# epoch 128, loss: 0.578022
# epoch 129, loss: 0.576114
# epoch 130, loss: 0.574234
# epoch 131, loss: 0.572379
# epoch 132, loss: 0.570552
# epoch 133, loss: 0.568748
# epoch 134, loss: 0.566969
# epoch 135, loss: 0.565213
# epoch 136, loss: 0.563476
# epoch 137, loss: 0.561765
# epoch 138, loss: 0.560078
# epoch 139, loss: 0.558415
# epoch 140, loss: 0.556771
# epoch 141, loss: 0.555147
# epoch 142, loss: 0.553542
# epoch 143, loss: 0.551958
# epoch 144, loss: 0.550395
# epoch 145, loss: 0.548855
# epoch 146, loss: 0.547333
# epoch 147, loss: 0.545829
# epoch 148, loss: 0.544346
# epoch 149, loss: 0.542883
# epoch 150, loss: 0.541438
# epoch 151, loss: 0.540010
# epoch 152, loss: 0.538603
# epoch 153, loss: 0.537211
# epoch 154, loss: 0.535838
# epoch 155, loss: 0.534483
# epoch 156, loss: 0.533143
# epoch 157, loss: 0.531821
# epoch 158, loss: 0.530518
# epoch 159, loss: 0.529228
# epoch 160, loss: 0.527958
# epoch 161, loss: 0.526702
# epoch 162, loss: 0.525462
# epoch 163, loss: 0.524238
# epoch 164, loss: 0.523030
# epoch 165, loss: 0.521836
# epoch 166, loss: 0.520658
# epoch 167, loss: 0.519494
# epoch 168, loss: 0.518344
# epoch 169, loss: 0.517210
# epoch 170, loss: 0.516090
# epoch 171, loss: 0.514984
# epoch 172, loss: 0.513889
# epoch 173, loss: 0.512810
# epoch 174, loss: 0.511746
# epoch 175, loss: 0.510691
# epoch 176, loss: 0.509651
# epoch 177, loss: 0.508621
# epoch 178, loss: 0.507608
# epoch 179, loss: 0.506607
# epoch 180, loss: 0.505618
# epoch 181, loss: 0.504641
# epoch 182, loss: 0.503675
# epoch 183, loss: 0.502723
# epoch 184, loss: 0.501780
# epoch 185, loss: 0.500851
# epoch 186, loss: 0.499933
# epoch 187, loss: 0.499026
# epoch 188, loss: 0.498129
# epoch 189, loss: 0.497243
# epoch 190, loss: 0.496365
# epoch 191, loss: 0.495502
# epoch 192, loss: 0.494650
# epoch 193, loss: 0.493808
# epoch 194, loss: 0.492974
# epoch 195, loss: 0.492153
# epoch 196, loss: 0.491343
# epoch 197, loss: 0.490538
# epoch 198, loss: 0.489746
# epoch 199, loss: 0.488965
# epoch 200, loss: 0.488193
# epoch 201, loss: 0.487430
# epoch 202, loss: 0.486677
# epoch 203, loss: 0.485932
# epoch 204, loss: 0.485195
# epoch 205, loss: 0.484467
# epoch 206, loss: 0.483750
# epoch 207, loss: 0.483041
# epoch 208, loss: 0.482339
# epoch 209, loss: 0.481648
# epoch 210, loss: 0.480964
# epoch 211, loss: 0.480290
# epoch 212, loss: 0.479623
# epoch 213, loss: 0.478963
# epoch 214, loss: 0.478311
# epoch 215, loss: 0.477669
# epoch 216, loss: 0.477035
# epoch 217, loss: 0.476409
# epoch 218, loss: 0.475787
# epoch 219, loss: 0.475173
# epoch 220, loss: 0.474568
# epoch 221, loss: 0.473970
# epoch 222, loss: 0.473377
# epoch 223, loss: 0.472795
# epoch 224, loss: 0.472218
# epoch 225, loss: 0.471650
# epoch 226, loss: 0.471087
# epoch 227, loss: 0.470531
# epoch 228, loss: 0.469984
# epoch 229, loss: 0.469440
# epoch 230, loss: 0.468905
# epoch 231, loss: 0.468377
# epoch 232, loss: 0.467854
# epoch 233, loss: 0.467337
# epoch 234, loss: 0.466829
# epoch 235, loss: 0.466326
# epoch 236, loss: 0.465829
# epoch 237, loss: 0.465338
# epoch 238, loss: 0.464852
# epoch 239, loss: 0.464371
# epoch 240, loss: 0.463897
# epoch 241, loss: 0.463429
# epoch 242, loss: 0.462967
# epoch 243, loss: 0.462510
# epoch 244, loss: 0.462059
# epoch 245, loss: 0.461613
# epoch 246, loss: 0.461171
# epoch 247, loss: 0.460736
# epoch 248, loss: 0.460306
# epoch 249, loss: 0.459881
# epoch 250, loss: 0.459462
# epoch 251, loss: 0.459047
# epoch 252, loss: 0.458638
# epoch 253, loss: 0.458234
# epoch 254, loss: 0.457834
# epoch 255, loss: 0.457439
# epoch 256, loss: 0.457049
# epoch 257, loss: 0.456664
# epoch 258, loss: 0.456283
# epoch 259, loss: 0.455907
# epoch 260, loss: 0.455535
# epoch 261, loss: 0.455167
# epoch 262, loss: 0.454805
# epoch 263, loss: 0.454449
# epoch 264, loss: 0.454095
# epoch 265, loss: 0.453745
# epoch 266, loss: 0.453397
# epoch 267, loss: 0.453055
# epoch 268, loss: 0.452720
# epoch 269, loss: 0.452386
# epoch 270, loss: 0.452058
# epoch 271, loss: 0.451730
# epoch 272, loss: 0.451409
# epoch 273, loss: 0.451092
# epoch 274, loss: 0.450778
# epoch 275, loss: 0.450469
# epoch 276, loss: 0.450162
# epoch 277, loss: 0.449859
# epoch 278, loss: 0.449562
# epoch 279, loss: 0.449266
# epoch 280, loss: 0.448974
# epoch 281, loss: 0.448686
# epoch 282, loss: 0.448401
# epoch 283, loss: 0.448120
# epoch 284, loss: 0.447842
# epoch 285, loss: 0.447568
# epoch 286, loss: 0.447296
# epoch 287, loss: 0.447028
# epoch 288, loss: 0.446764
# epoch 289, loss: 0.446503
# epoch 290, loss: 0.446246
# epoch 291, loss: 0.445990
# epoch 292, loss: 0.445737
# epoch 293, loss: 0.445488
# epoch 294, loss: 0.445242
# epoch 295, loss: 0.444998
# epoch 296, loss: 0.444758
# epoch 297, loss: 0.444522
# epoch 298, loss: 0.444288
# epoch 299, loss: 0.444056
# epoch 300, loss: 0.443828
# epoch 301, loss: 0.443601
# epoch 302, loss: 0.443378
# epoch 303, loss: 0.443158
# epoch 304, loss: 0.442940
# epoch 305, loss: 0.442725
# epoch 306, loss: 0.442513
# epoch 307, loss: 0.442303
# epoch 308, loss: 0.442094
# epoch 309, loss: 0.441889
# epoch 310, loss: 0.441686
# epoch 311, loss: 0.441486
# epoch 312, loss: 0.441289
# epoch 313, loss: 0.441094
# epoch 314, loss: 0.440899
# epoch 315, loss: 0.440709
# epoch 316, loss: 0.440521
# epoch 317, loss: 0.440336
# epoch 318, loss: 0.440155
# epoch 319, loss: 0.439970
# epoch 320, loss: 0.439790
# epoch 321, loss: 0.439613
# epoch 322, loss: 0.439437
# epoch 323, loss: 0.439264
# epoch 324, loss: 0.439093
# epoch 325, loss: 0.438925
# epoch 326, loss: 0.438758
# epoch 327, loss: 0.438594
# epoch 328, loss: 0.438431
# epoch 329, loss: 0.438270
# epoch 330, loss: 0.438112
# epoch 331, loss: 0.437954
# epoch 332, loss: 0.437799
# epoch 333, loss: 0.437645
# epoch 334, loss: 0.437494
# epoch 335, loss: 0.437345
# epoch 336, loss: 0.437196
# epoch 337, loss: 0.437049
# epoch 338, loss: 0.436904
# epoch 339, loss: 0.436762
# epoch 340, loss: 0.436621
# epoch 341, loss: 0.436482
# epoch 342, loss: 0.436345
# epoch 343, loss: 0.436209
# epoch 344, loss: 0.436076
# epoch 345, loss: 0.435943
# epoch 346, loss: 0.435812
# epoch 347, loss: 0.435682
# epoch 348, loss: 0.435554
# epoch 349, loss: 0.435427
# epoch 350, loss: 0.435302
# epoch 351, loss: 0.435179
# epoch 352, loss: 0.435058
# epoch 353, loss: 0.434937
# epoch 354, loss: 0.434820
# epoch 355, loss: 0.434702
# epoch 356, loss: 0.434584
# epoch 357, loss: 0.434470
# epoch 358, loss: 0.434356
# epoch 359, loss: 0.434243
# epoch 360, loss: 0.434132
# epoch 361, loss: 0.434023
# epoch 362, loss: 0.433915
# epoch 363, loss: 0.433808
# epoch 364, loss: 0.433705
# epoch 365, loss: 0.433600
# epoch 366, loss: 0.433496
# epoch 367, loss: 0.433394
# epoch 368, loss: 0.433294
# epoch 369, loss: 0.433195
# epoch 370, loss: 0.433097
# epoch 371, loss: 0.433002
# epoch 372, loss: 0.432905
# epoch 373, loss: 0.432811
# epoch 374, loss: 0.432717
# epoch 375, loss: 0.432625
# epoch 376, loss: 0.432535
# epoch 377, loss: 0.432444
# epoch 378, loss: 0.432354
# epoch 379, loss: 0.432266
# epoch 380, loss: 0.432180
# epoch 381, loss: 0.432094
# epoch 382, loss: 0.432009
# epoch 383, loss: 0.431925
# epoch 384, loss: 0.431843
# epoch 385, loss: 0.431761
# epoch 386, loss: 0.431680
# epoch 387, loss: 0.431602
# epoch 388, loss: 0.431523
# epoch 389, loss: 0.431445
# epoch 390, loss: 0.431368
# epoch 391, loss: 0.431292
# epoch 392, loss: 0.431215
# epoch 393, loss: 0.431141
# epoch 394, loss: 0.431068
# epoch 395, loss: 0.430995
# epoch 396, loss: 0.430924
# epoch 397, loss: 0.430853
# epoch 398, loss: 0.430784
# epoch 399, loss: 0.430714
# epoch 400, loss: 0.430647
# epoch 401, loss: 0.430578
# epoch 402, loss: 0.430512
# epoch 403, loss: 0.430446
# epoch 404, loss: 0.430381
# epoch 405, loss: 0.430316
# epoch 406, loss: 0.430253
# epoch 407, loss: 0.430190
# epoch 408, loss: 0.430129
# epoch 409, loss: 0.430068
# epoch 410, loss: 0.430009
# epoch 411, loss: 0.429948
# epoch 412, loss: 0.429889
# epoch 413, loss: 0.429830
# epoch 414, loss: 0.429773
# epoch 415, loss: 0.429717
# epoch 416, loss: 0.429662
# epoch 417, loss: 0.429606
# epoch 418, loss: 0.429552
# epoch 419, loss: 0.429497
# epoch 420, loss: 0.429442
# epoch 421, loss: 0.429389
# epoch 422, loss: 0.429337
# epoch 423, loss: 0.429285
# epoch 424, loss: 0.429234
# epoch 425, loss: 0.429183
# epoch 426, loss: 0.429134
# epoch 427, loss: 0.429085
# epoch 428, loss: 0.429036
# epoch 429, loss: 0.428988
# epoch 430, loss: 0.428941
# epoch 431, loss: 0.428894
# epoch 432, loss: 0.428847
# epoch 433, loss: 0.428802
# epoch 434, loss: 0.428757
# epoch 435, loss: 0.428712
# epoch 436, loss: 0.428668
# epoch 437, loss: 0.428624
# epoch 438, loss: 0.428582
# epoch 439, loss: 0.428539
# epoch 440, loss: 0.428498
# epoch 441, loss: 0.428456
# epoch 442, loss: 0.428415
# epoch 443, loss: 0.428375
# epoch 444, loss: 0.428335
# epoch 445, loss: 0.428297
# epoch 446, loss: 0.428257
# epoch 447, loss: 0.428217
# epoch 448, loss: 0.428180
# epoch 449, loss: 0.428142
# epoch 450, loss: 0.428105
# epoch 451, loss: 0.428069
# epoch 452, loss: 0.428032
# epoch 453, loss: 0.427996
# epoch 454, loss: 0.427960
# epoch 455, loss: 0.427926
# epoch 456, loss: 0.427892
# epoch 457, loss: 0.427857
# epoch 458, loss: 0.427824
# epoch 459, loss: 0.427791
# epoch 460, loss: 0.427761
# epoch 461, loss: 0.427728
# epoch 462, loss: 0.427696
# epoch 463, loss: 0.427663
# epoch 464, loss: 0.427630
# epoch 465, loss: 0.427598
# epoch 466, loss: 0.427569
# epoch 467, loss: 0.427538
# epoch 468, loss: 0.427507
# epoch 469, loss: 0.427478
# epoch 470, loss: 0.427448
# epoch 471, loss: 0.427420
# epoch 472, loss: 0.427391
# epoch 473, loss: 0.427363
# epoch 474, loss: 0.427335
# epoch 475, loss: 0.427308
# epoch 476, loss: 0.427281
# epoch 477, loss: 0.427254
# epoch 478, loss: 0.427228
# epoch 479, loss: 0.427201
# epoch 480, loss: 0.427175
# epoch 481, loss: 0.427150
# epoch 482, loss: 0.427125
# epoch 483, loss: 0.427100
# epoch 484, loss: 0.427075
# epoch 485, loss: 0.427051
# epoch 486, loss: 0.427027
# epoch 487, loss: 0.427004
# epoch 488, loss: 0.426980
# epoch 489, loss: 0.426957
# epoch 490, loss: 0.426934
# epoch 491, loss: 0.426911
# epoch 492, loss: 0.426889
# epoch 493, loss: 0.426867
# epoch 494, loss: 0.426845
# epoch 495, loss: 0.426823
# epoch 496, loss: 0.426802
# epoch 497, loss: 0.426781
# epoch 498, loss: 0.426760
# epoch 499, loss: 0.426740
# epoch 500, loss: 0.426720
